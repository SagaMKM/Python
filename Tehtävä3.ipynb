# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

#plt.style.use('seaborn-whitegrid')

# %%
df = pd.read_excel('autoMPG_data.xlsx')

# %%
ddf= df.drop(["GallonsPer100MilesTo1981", "MPG", "Year", "Year70To81", "Origin", "Origin.Eq.1", "Origin.Eq.2", "Origin.Eq.3", "Name"], axis=1)

# %%
ddf.head()
# Out:
#    GallonsPer100Miles  Cylinders  Displacement100ci  Horsepower100  \
# 0            5.555556          8               3.07           1.30
# 1            6.666667          8               3.50           1.65
# 2            5.555556          8               3.18           1.50
# 3            6.250000          8               3.04           1.50
# 4            5.882353          8               3.02           1.40
#
#    Weight1000lb  Seconds0to60
# 0         3.504          12.0
# 1         3.693          11.5
# 2         3.436          11.0
# 3         3.433          12.0
# 4         3.449          10.5

# %%
ddf['Weight1000lb'].hist()
# Out:
# <AxesSubplot:>

# %%
ddf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   GallonsPer100Miles  392 non-null    float64
#  1   Cylinders           392 non-null    int64
#  2   Displacement100ci   392 non-null    float64
#  3   Horsepower100       392 non-null    float64
#  4   Weight1000lb        392 non-null    float64
#  5   Seconds0to60        392 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 18.5 KB

# %%
ddf.describe()
# Out:
#        GallonsPer100Miles   Cylinders  Displacement100ci  Horsepower100  \
# count          392.000000  392.000000          392.00000     392.000000
# mean             4.782243    5.471939            1.94412       1.044694
# std              1.663944    1.705783            1.04644       0.384912
# min              2.145923    3.000000            0.68000       0.460000
# 25%              3.448276    4.000000            1.05000       0.750000
# 50%              4.396135    4.000000            1.51000       0.935000
# 75%              5.882353    8.000000            2.75750       1.260000
# max             11.111111    8.000000            4.55000       2.300000
#
#        Weight1000lb  Seconds0to60
# count    392.000000    392.000000
# mean       2.977584     15.541327
# std        0.849403      2.758864
# min        1.613000      8.000000
# 25%        2.225250     13.775000
# 50%        2.803500     15.500000
# 75%        3.614750     17.025000
# max        5.140000     24.800000

# %% [markdown]
# SCATTERPLOTS

# %%
sns.pairplot(ddf, kind = 'reg')

# %%
X = df['Weight1000lb'].to_frame()

# %% [markdown]
# KORRELLAATIO

# %%
ddf.corr()
# Out:
#                     GallonsPer100Miles  Cylinders  Displacement100ci  \
# GallonsPer100Miles            1.000000   0.839385           0.866050
# Cylinders                     0.839385   1.000000           0.950823
# Displacement100ci             0.866050   0.950823           1.000000
# Horsepower100                 0.854809   0.842983           0.897257
# Weight1000lb                  0.885056   0.897527           0.932994
# Seconds0to60                 -0.456338  -0.504683          -0.543800
#
#                     Horsepower100  Weight1000lb  Seconds0to60
# GallonsPer100Miles       0.854809      0.885056     -0.456338
# Cylinders                0.842983      0.897527     -0.504683
# Displacement100ci        0.897257      0.932994     -0.543800
# Horsepower100            1.000000      0.864538     -0.689196
# Weight1000lb             0.864538      1.000000     -0.416839
# Seconds0to60            -0.689196     -0.416839      1.000000

# %%
sns.heatmap(ddf.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Suurimmat korrellaatiot: Moottorin koko ja auton paino

# %%
ax1 = sns.jointplot(data = ddf, x = 'GallonsPer100Miles', y = 'Weight1000lb')

# %%
# Let's prepare the data for the regression model
x = ddf[['Weight1000lb','Displacement100ci', 'Horsepower100']]

# %%
Y = ddf['GallonsPer100Miles']

# %%
fuel_model.coef_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [15], line 1
# ----> 1 fuel_model.coef_
#
# NameError: name 'fuel_model' is not defined

# %%
fuel_model.intercept_
# Out:
# -0.012235972571573939

# %% [markdown]
# EXTRAPOLATION PREDICTION

# %%
fuel_model.predict(pd.DataFrame([[1000,0.1,300]]))
# Out:
# c:\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1451.8081178])

# %%
plt.scatter(fuel_model.predict(x), fuel_model.predict(x)-Y)

plt.hlines(y=0,xmin=2,xmax=9)

# %% [markdown]
# Selittää datan 81,5 prosenttisesti

# %%
#Coefficient of determination
fuel_model.score(x,Y)
# Out:
# 0.8158213878482583

# %% [markdown]
# Models

# %%
y = df['GallonsPer100Miles']
XWEIGHT = df['Weight1000lb'].to_frame()
X1 = df[['Cylinders', 'Displacement100ci', 'Horsepower100', 'Weight1000lb', 'Seconds0to60']]
X2 = df[['Displacement100ci', 'Horsepower100', 'Weight1000lb']]
X3 = df[['Displacement100ci', 'Weight1000lb']]
X4 = df[['Cylinders', 'Horsepower100']]
X5 = df[['Cylinders', 'Displacement100ci']]
X6 = df[['Displacement100ci', 'Horsepower100']]
X7 = df[['Weight1000lb', 'Seconds0to60']]
X8 = df[['Weight1000lb', 'Horsepower100']]

# %%
fuel_modelWEIGHT = LinearRegression().fit(XWEIGHT,y)

# %%
fuel_modelWEIGHT.predict([[1]])
# Out:
# c:\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1.35353236])

# %%
fuel_model1 = LinearRegression().fit(X1,y)
fuel_model2 = LinearRegression().fit(X2,y)
fuel_model3 = LinearRegression().fit(X3,y)
fuel_model4 = LinearRegression().fit(X4,y)
fuel_model5 = LinearRegression().fit(X5,y)
fuel_model6 = LinearRegression().fit(X6,y)
fuel_model7 = LinearRegression().fit(X7,y)
fuel_model8 = LinearRegression().fit(X8,y)

# %%
#fuel_model1.predict(X1)
print(fuel_model1.score(X1,y))
print(fuel_model2.score(X2,y))
print(fuel_model3.score(X3,y))
print(fuel_model4.score(X4,y))
print(fuel_model5.score(X5,y))
print(fuel_model6.score(X6,y))
print(fuel_model7.score(X7,y))
print(fuel_model8.score(X8,y))
# Out:
# 0.8207948199718269
# 0.8158213878482583
# 0.7958617550554248
# 0.7794651426587467
# 0.7526856299447539
# 0.7810452743689287
# 0.7925717591364054
# 0.8151407991970328

# %% [markdown]
# Displacement100ci    +     Horsepower100      +     Weight1000lb

# %%
fuel_model8.predict([[1.5, 3]])
# Out:
# c:\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([6.1086204])

# %%
ddf['Displacement100ci'].max()
# Out:
# 4.55

# %%
ddf['Displacement100ci'].min()
# Out:
# 0.68

# %% [markdown]
# _______________________________________________

# %%
ddf['Horsepower100'].max()
# Out:
# 2.3

# %%
ddf['Horsepower100'].min()
# Out:
# 0.46

# %% [markdown]
# ________________________________________________________________________

# %%
ddf['Weight1000lb'].max()
# Out:
# 5.14

# %%
ddf['Weight1000lb'].min()
# Out:
# 1.613
